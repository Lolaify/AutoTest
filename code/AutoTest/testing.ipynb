# %%
import analysis as a

# %%
dirty_path =
clean_path =
res_path = "/home/micro/Documents/Code/AutoTest/final_results/AutoTest_w_fixes_wip/detected_outliers/rt_train/rt_train_selected_sdc_on_Benchmarks_st_bench_dirty.csv"
